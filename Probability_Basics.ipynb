# %% [markdown]
# #Probability Basics

# %% [markdown]
# 1.Question 1: A die is rolled. What is the probability of getting:
#
# (a) An even number
#
# (b) A number greater than 4
# - A die has 6 outcomes: {1, 2, 3, 4, 5, 6}
#
# (a) Probability of getting an even number
#
# Even numbers = {2, 4, 6} → 3 outcomes
# P(Even)=3/6​=1/2
#
# (b) Probability of getting a number greater than 4
#
# Numbers> 4 = {5, 6} → 2 outcomes
#
# 𝑃(Number>4)= 2/6= 1/3
#
#
# 2. Question: In a class of 50 students:
#
# 20 like Mathematics (M)
#
# 15 like Science (S)
#
# 5 like both subjects
#
# What is the probability that a student chosen at random likes Mathematics or Science?
# - Total students = 50
# Given: n(M)=20
#        n(S)=15
#        n(M ∩ S)
#
#        n(M ∪ S) =n(M) + n(S) − n(M ∩ S)
#        n(M ∪ S) = 20 + 15 − 5 = 30
#
#        P(M or S)= 30/50 = 3/5
#
#
# 3. Question 3: A bag has 3 red and 2 blue balls. If one ball is drawn randomly and is red, what is the probability
# that the next ball is also red (without replacement)?
# - Total balls = 3 red + 2 blue = 5
#
# First ball is red (given), now remaining balls:
#
# Red = 2
#
# Total = 4
# P(Next ball is red)= 2/4 = 1/2
#
# 4. Question 4: The population of a school is divided into 60% boys and 40% girls. If you want equal representation
# of both genders in the sample, which method should you use: Simple Random Sampling or Stratified Sampling?
# Why?
# - To get equal representation of boys and girls, we should use:
#
# Stratified Sampling
#
# Reason:
#
# Population is divided into groups (boys and girls).
#
# Samples are selected proportionally from each group.
#
# Ensures fair and accurate representation.
#
# Simple Random Sampling may cause imbalance.
#
# 5. Question 5: The average height of 1000 students = 160 cm. A sample of 100 students shows an average height
# = 158 cm.
#
# Find the sampling error.
#
# - Population mean = 160 cm
# Sample mean = 158 cm
#
# Sampling Error=
# Sample Mean − Population Mean
# Sampling Error = Sample Mean − Population Mean = 158 − 160= −2cm
# =158−160=−2 cm
#
# Sampling error = −2 cm (sample mean is 2 cm less)
#
# 6. Question 6: The population mean salary is ₹50,000 with σ = ₹5,000. If we take a sample of 100 employees, what  is the standard error of the mean (SEM)?
# - Population standard deviation σ = 5000
#  Sample size n=100
#  SEM= 𝜎/underoot n
#  SEM=5000/underoot 100 = 5000/10 = 500
#  Standard Error of Mean = ₹500
#
# 7. Question 7: In a group of 100 students:
#
# 40 like Cricket (C)
#
# 30 like Football (F)
#
# 10 like both Cricket and Football
#
# Find the probability that a student likes at least one sport.
# - Total students = 100
#
# 𝑛 (𝐶) = 40
# n(F) = 3
# n(C ∩ F) = 10
#
# n(C ∪ F) = 40 + 30 − 10 = 60
# P(At least one sport)= 60/100 = 3/5
#
# 8. Question 8: From a deck of 52 cards, two cards are drawn without replacement. What is the probability that
# both are Aces?
# - Total cards = 52
# Number of Aces = 4
#
# Probability first card is Ace: 4/52
#
# Probability second card is Ace:3/51
#
# P(Both Aces)= 4/52 * 3/51 = 12/2652 = 1/221
#
# 9. Question 9: A factory produces bulbs with 2% defective rate. If 5 bulbs are chosen at random, what is the
# probability that all are non-defective?
# - Defective rate = 2%
# So non-defective rate = 98% = 0.98
#
# P(All non-defective)=(0.98)^5 = 0.9039 (approx)
#
# 10. Question 10: Differentiate between discrete and continuous random variables with examples.
# - Discrete vs Continuous Random Variables
#
# Discrete Random Variable	    Continuous Random Variable
# Takes countable values	      Takes infinite values
# Values are separate     	    Values are continuous
# Example: Number of students	  Example: Height of students
# Example: Number of cars	      Example: Weight, time

# %% [markdown]
# 1.Question 1: A die is rolled. What is the probability of getting:
#
# (a) An even number
#
# (b) A number greater than 4
# - A die has 6 outcomes: {1, 2, 3, 4, 5, 6}
#
# (a) Probability of getting an even number
#
# Even numbers = {2, 4, 6} → 3 outcomes
# P(Even)=3/6​=1/2
#
# (b) Probability of getting a number greater than 4
#
# Numbers> 4 = {5, 6} → 2 outcomes
#
# 𝑃(Number>4)= 2/6= 1/3
#
#
# 2. Question: In a class of 50 students:
#
# 20 like Mathematics (M)
#
# 15 like Science (S)
#
# 5 like both subjects
#
# What is the probability that a student chosen at random likes Mathematics or Science?
# - Total balls = 3 red + 2 blue = 5
#
# First ball is red (given), now remaining balls:
#
# Red = 2
#
# Total = 4
#
# P (Next ball is red) =  2/4 = 1/2
#
# 3. Question 3: A bag has 3 red and 2 blue balls. If one ball is drawn randomly and is red, what is the probability
# that the next ball is also red (without replacement)?
# -
# 4. Question 4: The population of a school is divided into 60% boys and 40% girls. If you want equal representation
# of both genders in the sample, which method should you use: Simple Random Sampling or Stratified Sampling?
# Why?
# -
# 5. Question 5: The average height of 1000 students = 160 cm. A sample of 100 students shows an average height
# = 158 cm.
#
# Find the sampling error.
# -
# 6. Question 6: The population mean salary is ₹50,000 with σ = ₹5,000. If we take a sample of 100 employees, what  is the standard error of the mean (SEM)?
# -
# 7. Question 7: In a group of 100 students:
#
# 40 like Cricket (C)
#
# 30 like Football (F)
#
# 10 like both Cricket and Football
#
# Find the probability that a student likes at least one sport.
# -
# 8. Question 8: From a deck of 52 cards, two cards are drawn without replacement. What is the probability that
# both are Aces?
# -
# 9. Question 9: A factory produces bulbs with 2% defective rate. If 5 bulbs are chosen at random, what is the
# probability that all are non-defective?
# -
# 10. Question 10: Differentiate between discrete and continuous random variables with examples.
# -
